# %%
# IN THIS MODULE: IMPORTS, CNN, TRAIN, TEST, MNIS_FUNCTION, SPACE

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.skopt import SkOptSearch
from ray import tune
from ray.tune.suggest.bayesopt import BayesOptSearch
import time
import ray
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.ax import AxSearch
import argparse
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.nevergrad import NevergradSearch
import nevergrad as ng
import json
import os
from ray.tune import Trainable
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.zoopt import ZOOptSearch
from ray.tune.schedulers import AsyncHyperBandScheduler
from zoopt import ValueType
import torch
# IN THIS MODULE: IMPORTS, CNN, TRAIN, TEST, MNIS_FUNCTION, SPACE

import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.skopt import SkOptSearch
from ray import tune
from ray.tune.suggest.bayesopt import BayesOptSearch
import time
import ray
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.ax import AxSearch
import argparse
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.nevergrad import NevergradSearch
import nevergrad as ng
import json
import os
from ray.tune import Trainable
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
#from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.zoopt import ZOOptSearch
from ray.tune.schedulers import AsyncHyperBandScheduler
from zoopt import ValueType
import torch
import adabelief_pytorch
global_checkpoint_period=np.inf

def GAN_MNIST(SA):
    import ray

    import os
    import torch
    import torch.nn as nn
    import torch.nn.parallel
    import torch.utils.data
    import torchvision.datasets as dset
    import torchvision.transforms as transforms
    import torchvision.utils as vutils
    import numpy as np

    import ray
    from ray import tune
    from ray.tune.trial import ExportFormat
    from ray.tune.schedulers import PopulationBasedTraining

    import argparse
    import os
    from filelock import FileLock
    import random
    import torch
    import torch.nn as nn
    import torch.nn.parallel
    import torch.optim as optim
    import torch.utils.data
    import numpy as np
    from ray.tune.suggest.bayesopt import BayesOptSearch
    from ray.tune.suggest.ax import AxSearch



    from torch.autograd import Variable
    from torch.nn import functional as F
    from scipy.stats import entropy

    import matplotlib.pyplot as plt
    import matplotlib.animation as animation

    # Training parameters
    dataroot = ray.utils.get_user_temp_dir() + os.sep
    workers = 2
    batch_size = 64
    image_size = 32

    # Number of channels in the training images. For color images this is 3
    nc = 1

    # Size of z latent vector (i.e. size of generator input)
    nz = 100

    # Size of feature maps in generator
    ngf = 32

    # Size of feature maps in discriminator
    ndf = 32

    # Beta1 hyperparam for Adam optimizers
    beta1 = 0.5

    # iterations of actual training in each Trainable _train
    train_iterations_per_step = 5

    MODEL_PATH = os.path.expanduser("~/.ray/models/mnist_cnn.pt")


    def get_data_loader():
        dataset = dset.MNIST(
            root=dataroot,
            download=True,
            transform=transforms.Compose([
                transforms.Resize(image_size),
                transforms.ToTensor(),
                transforms.Normalize((0.5, ), (0.5, )),
            ]))

        # Create the dataloader
        dataloader = torch.utils.data.DataLoader(
            dataset, batch_size=batch_size, shuffle=True, num_workers=workers)

        return dataloader


    # __GANmodel_begin__
    # custom weights initialization called on netG and netD
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find("Conv") != -1:
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        elif classname.find("BatchNorm") != -1:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)


    # Generator Code
    class Generator(nn.Module):
        def __init__(self):
            super(Generator, self).__init__()
            self.main = nn.Sequential(
                # input is Z, going into a convolution
                nn.ConvTranspose2d(nz, ngf * 4, 4, 1, 0, bias=False),
                nn.BatchNorm2d(ngf * 4),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf * 2),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
                nn.Tanh())

        def forward(self, input):
            return self.main(input)


    class Discriminator(nn.Module):
        def __init__(self):
            super(Discriminator, self).__init__()
            self.main = nn.Sequential(
                nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ndf * 2), nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ndf * 4), nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 4, 1, 4, 1, 0, bias=False), nn.Sigmoid())

        def forward(self, input):
            return self.main(input)


    # __GANmodel_end__


    # __INCEPTION_SCORE_begin__
    class Net(nn.Module):
        """
        LeNet for MNist classification, used for inception_score
        """

        def __init__(self):
            super(Net, self).__init__()
            self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
            self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
            self.conv2_drop = nn.Dropout2d()
            self.fc1 = nn.Linear(320, 50)
            self.fc2 = nn.Linear(50, 10)

        def forward(self, x):
            x = F.relu(F.max_pool2d(self.conv1(x), 2))
            x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
            x = x.view(-1, 320)
            x = F.relu(self.fc1(x))
            x = F.dropout(x, training=self.training)
            x = self.fc2(x)
            return F.log_softmax(x, dim=1)


    def inception_score(imgs, mnist_model_ref, batch_size=32, splits=1):
        N = len(imgs)
        dtype = torch.FloatTensor
        dataloader = torch.utils.data.DataLoader(imgs, batch_size=batch_size)
        cm = ray.get(mnist_model_ref)  # Get the mnist model from Ray object store.
        up = nn.Upsample(size=(28, 28), mode="bilinear").type(dtype)

        def get_pred(x):
            x = up(x)
            x = cm(x)
            return F.softmax(x).data.cpu().numpy()

        preds = np.zeros((N, 10))
        for i, batch in enumerate(dataloader, 0):
            batch = batch.type(dtype)
            batchv = Variable(batch)
            batch_size_i = batch.size()[0]
            preds[i * batch_size:i * batch_size + batch_size_i] = get_pred(batchv)

        # Now compute the mean kl-div
        split_scores = []
        for k in range(splits):
            part = preds[k * (N // splits):(k + 1) * (N // splits), :]
            py = np.mean(part, axis=0)
            scores = []
            for i in range(part.shape[0]):
                pyx = part[i, :]
                scores.append(entropy(pyx, py))
            split_scores.append(np.exp(np.mean(scores)))

        return np.mean(split_scores), np.std(split_scores)


    # __INCEPTION_SCORE_end__


    def train(netD, netG, optimG, optimD, criterion, dataloader, iteration, device,
              mnist_model_ref):
        real_label = 1
        fake_label = 0

        for i, data in enumerate(dataloader, 0):
            if i >= train_iterations_per_step:
                break

            netD.zero_grad()
            real_cpu = data[0].to(device)
            b_size = real_cpu.size(0)
            label = torch.full(
                (b_size, ), real_label, dtype=torch.float, device=device)
            output = netD(real_cpu).view(-1)
            errD_real = criterion(output, label)
            errD_real.backward()
            D_x = output.mean().item()

            noise = torch.randn(b_size, nz, 1, 1, device=device)
            fake = netG(noise)
            label.fill_(fake_label)
            output = netD(fake.detach()).view(-1)
            errD_fake = criterion(output, label)
            errD_fake.backward()
            D_G_z1 = output.mean().item()
            errD = errD_real + errD_fake
            optimD.step()

            netG.zero_grad()
            label.fill_(real_label)
            output = netD(fake).view(-1)
            errG = criterion(output, label)
            errG.backward()
            D_G_z2 = output.mean().item()
            optimG.step()

            is_score, is_std = inception_score(fake, mnist_model_ref)

            # Output training stats
           # if iteration % 10 == 0:
            #    print("[%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z))"
             #         ": %.4f / %.4f \tInception score: %.4f" %
              #        (iteration, len(dataloader), errD.item(), errG.item(), D_x,
               #        D_G_z1, D_G_z2, is_score))

        return errG.item(), errD.item(), is_score


    def plot_images(dataloader):
        # Plot some training images
        if 1==0:
            real_batch = next(iter(dataloader))
            plt.figure(figsize=(8, 8))
            plt.axis("off")
            plt.title("Original Images")
            plt.imshow(
                np.transpose(
                    vutils.make_grid(real_batch[0][:64], padding=2,
                                     normalize=True).cpu(), (1, 2, 0)))

            plt.show()


    def demo_gan(checkpoint_paths):
        img_list = []
        fixed_noise = torch.randn(64, nz, 1, 1)
        for netG_path in checkpoint_paths:
            loadedG = Generator()
            loadedG.load_state_dict(torch.load(netG_path)["netGmodel"])
            with torch.no_grad():
                fake = loadedG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        fig = plt.figure(figsize=(8, 8))
        plt.axis("off")
        ims = [[plt.imshow(np.transpose(i, (1, 2, 0)), animated=True)]
               for i in img_list]
        ani = animation.ArtistAnimation(
            fig, ims, interval=1000, repeat_delay=1000, blit=True)
        ani.save("./generated" +str(SA)+"best.gif", writer="imagemagick", dpi=72)
        plt.show()




    # __Trainable_begin__
    class PytorchTrainable(tune.Trainable):
        def setup(self, config):
            use_cuda = config.get("use_gpu") and torch.cuda.is_available()
            self.device = torch.device("cuda" if use_cuda else "cpu")
            self.netD = Discriminator().to(self.device)
            self.netD.apply(weights_init)
            self.netG = Generator().to(self.device)
            self.netG.apply(weights_init)
            self.criterion = nn.BCELoss()    
            self.optimizerD =optim.Adam(
                self.netD.parameters(),
                lr=config.get("lr", 0.01),
                betas=(beta1, 0.999))
            self.optimizerG =optim.Adam(
                self.netG.parameters(),
                lr=config.get("lr", 0.01),
                betas=(beta1, 0.999))

            with FileLock(os.path.expanduser("~/.data.lock")):
                self.dataloader = get_data_loader()
            self.mnist_model_ref = c["mnist_model_ref"]

        def step(self):
            lossG, lossD, is_score = train(self.netD, self.netG, self.optimizerG,
                                           self.optimizerD, self.criterion,
                                           self.dataloader, self._iteration,
                                           self.device, self.mnist_model_ref)
            return {"lossg": lossG, "lossd": lossD, "is_score": is_score}

        def save_checkpoint(self, checkpoint_dir):
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save({
                "netDmodel": self.netD.state_dict(),
                "netGmodel": self.netG.state_dict(),
                "optimD": self.optimizerD.state_dict(),
                "optimG": self.optimizerG.state_dict(),
            }, path)

            return checkpoint_dir

        def load_checkpoint(self, checkpoint_dir):
            path = os.path.join(checkpoint_dir, "checkpoint")
            checkpoint = torch.load(path)
            self.netD.load_state_dict(checkpoint["netDmodel"])
            self.netG.load_state_dict(checkpoint["netGmodel"])
            self.optimizerD.load_state_dict(checkpoint["optimD"])
            self.optimizerG.load_state_dict(checkpoint["optimG"])

        def reset_config(self, new_config):
            if "netD_lr" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["lr"] = 10**-(new_config["netD_lr"])
            if "netG_lr" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["lr"] = 10**-(new_config["netG_lr"])
            if "netD_B" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["betas"] = (10**-(new_config["netD_B"]),0.999)
            if "netG_B" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["betas"] = (10**-(new_config["netG_B"]),0.999)
            if "weight_decay1" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["weight_decay"] = 10**-(new_config["weight_decay1"])
            if "weight_decay2" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["weight_decay"] = 10**-(new_config["weight_decay2"])
            self.config = new_config
            return True

        def _export_model(self, export_formats, export_dir):
            if export_formats == [ExportFormat.MODEL]:
                path = os.path.join(export_dir, "exported_models")
                torch.save({
                    "netDmodel": self.netD.state_dict(),
                    "netGmodel": self.netG.state_dict()
                }, path)
                return {ExportFormat.MODEL: path}
            else:
                raise ValueError("unexpected formats: " + str(export_formats))



    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--smoke-test", action="store_true", help="Finish quickly for testing")
    args, _ = parser.parse_known_args()
    import urllib.request
    # Download a pre-trained MNIST model for inception score calculation.
    # This is a tiny model (<100kb).
    if not os.path.exists(MODEL_PATH):
        print("downloading model")
        os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
        urllib.request.urlretrieve(
            "https://github.com/ray-project/ray/raw/master/python/ray/tune/"
            "examples/pbt_dcgan_mnist/mnist_cnn.pt", MODEL_PATH)

    dataloader = get_data_loader()
    if not args.smoke_test:
        plot_images(dataloader)

    # load the pretrained mnist classification model for inception_score
    mnist_cnn = Net()
    mnist_cnn.load_state_dict(torch.load(MODEL_PATH))
    mnist_cnn.eval()
    mnist_model_ref = ray.put(mnist_cnn)

    # __tune_begin__
    scheduler = PopulationBasedTraining(
        time_attr="training_iteration",
        perturbation_interval=5,
        hyperparam_mutations={
            # distribution for resampling
            "netG_lr": lambda: np.random.uniform(1, 9),
            "netD_lr": lambda: np.random.uniform(1, 9),
            "netD_B": lambda: np.random.uniform(0, 2),
            "netD_B": lambda: np.random.uniform(0, 2),
            "weight_decay1":lambda: np.random.uniform(3, 8),
            "weight_decay2":lambda: np.random.uniform(3, 8)
        })
    c={"mnist_model_ref" : mnist_model_ref}


    experiment_metrics= dict(metric="is_score",
        mode="max")

 
    
    if(SA==0):
        algo = HyperOptSearch(**experiment_metrics)
        name="hypher"

    if(SA==1):
        algo =   BayesOptSearch(**experiment_metrics) 
        name="Bayes"
        
    if(SA==2):
        algo = AxSearch(
            max_concurrent=2, #was working with 2
            **experiment_metrics
        )
        name="AX"

        
        
    if(SA==3):
        algo = NevergradSearch(
            optimizer=ng.optimizers.CMA,**experiment_metrics
            # space=space,  # If you want to set the space manually
            )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="NG"

        
     
    if(SA==4):
        algo = NevergradSearch(
            optimizer=ng.optimizers.TwoPointsDE,**experiment_metrics
            # space=space,  # If you want to set the space manually
            )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="NG2DE"

        
        
    if(SA==5):
        algo = NevergradSearch(
        optimizer=ng.optimizers.RandomSearch,**experiment_metrics
        # space=space,  # If you want to set the space manually
        )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="random"
                
    if(SA==6):
        dim_dict = {
        "netG_lr": (ValueType.CONTINUOUS, [0, 0.1], 1e-2),
        "netD_lr": (ValueType.CONTINUOUS, [0, 0.1], 1e-2)
        }
        algo = ZOOptSearch(
        algo="Asracos",  # only support Asracos currently
        #dim_dict=dim_dict,
      #  dim_dict=dim_dict,

        budget=100,
            **experiment_metrics
        #dim_dict=dim_dict,
       #     **zoopt_search_config,
        )
        name="zoo"


  #  if(SA!=4):
   #     scheduler = AsyncHyperBandScheduler(**experiment_metrics)
        
        
    os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)

    tune_kwargs = {
    "num_samples": 128 if args.smoke_test else 128,
      "stop":{
            "training_iteration": 200,
        },  

    "config": {
     "lr1":  tune.uniform(2, 5) #tune.uniform(1e-4, 0.1 ),#,1e-4), #*10
    , "lr2":  tune.uniform(2, 5) #tune.uniform(1e-4, 0.1 ),#,1e-4), #*10
    ,     "weight_decay1":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0
    ,     "weight_decay2":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0    
    ,     "beta1":2 #tune.uniform(1, 5),#,1e-4), #*10 et 0
     ,    "beta2":1 #tune.uniform(1, 5),#,1e-4), #*10 et 0
      ,  "adam1":0#tune.uniform(0,1),
      ,  "adam2":0#tune.uniform(0,1),
        }
    }
    def trial_name_id(trial):
        return f"{trial.trainable_name}_{trial.trial_id}"

    analysis = tune.run(
    PytorchTrainable,
    name=name,
    scheduler=scheduler,
    reuse_actors=True,
    search_alg=algo,
    verbose=2,
    checkpoint_at_end=True,
    num_samples=10,
   # export_formats=[ExportFormat.MODEL],
        config =     {
            "netG_lr": tune.uniform(1, 9),
           "netD_lr": tune.uniform(1, 9),
            "netG_B": tune.uniform(0, 2),
           "netD_B": tune.uniform(0, 2),
            "weight_decay1":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0
    ,     "weight_decay2":tune.uniform(3, 8)
        },      stop={
            "training_iteration": 200,
        },        metric="is_score",
        mode="max")
     ##             loggers=[TestLogger])

    all_trials = analysis.trials
    checkpoint_paths = [
        os.path.join(analysis.get_best_checkpoint(t), "checkpoint")
        for t in all_trials
    ]
    demo_gan(checkpoint_paths)

# %%
# IN THIS MODULE: IMPORTS, CNN, TRAIN, TEST, MNIS_FUNCTION, SPACE

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.skopt import SkOptSearch
from ray import tune
from ray.tune.suggest.bayesopt import BayesOptSearch
import time
import ray
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.ax import AxSearch
import argparse
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.nevergrad import NevergradSearch
import nevergrad as ng
import json
import os
from ray.tune import Trainable
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.zoopt import ZOOptSearch
from ray.tune.schedulers import AsyncHyperBandScheduler
from zoopt import ValueType
import torch
# IN THIS MODULE: IMPORTS, CNN, TRAIN, TEST, MNIS_FUNCTION, SPACE

import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.skopt import SkOptSearch
from ray import tune
from ray.tune.suggest.bayesopt import BayesOptSearch
import time
import ray
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.ax import AxSearch
import argparse
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.nevergrad import NevergradSearch
import nevergrad as ng
import json
import os
from ray.tune import Trainable
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.schedulers import AsyncHyperBandScheduler
#from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.zoopt import ZOOptSearch
from ray.tune.schedulers import AsyncHyperBandScheduler
from zoopt import ValueType
import torch
import adabelief_pytorch
global_checkpoint_period=np.inf

def GAN_MNIST_ZO(SA):
    import ray

    import os
    import torch
    import torch.nn as nn
    import torch.nn.parallel
    import torch.utils.data
    import torchvision.datasets as dset
    import torchvision.transforms as transforms
    import torchvision.utils as vutils
    import numpy as np

    import ray
    from ray import tune
    from ray.tune.trial import ExportFormat
    from ray.tune.schedulers import PopulationBasedTraining

    import argparse
    import os
    from filelock import FileLock
    import random
    import torch
    import torch.nn as nn
    import torch.nn.parallel
    import torch.optim as optim
    import torch.utils.data
    import numpy as np
    from ray.tune.suggest.bayesopt import BayesOptSearch
    from ray.tune.suggest.ax import AxSearch



    from torch.autograd import Variable
    from torch.nn import functional as F
    from scipy.stats import entropy

    import matplotlib.pyplot as plt
    import matplotlib.animation as animation

    # Training parameters
    dataroot = ray.utils.get_user_temp_dir() + os.sep
    workers = 2
    batch_size = 64
    image_size = 32

    # Number of channels in the training images. For color images this is 3
    nc = 1

    # Size of z latent vector (i.e. size of generator input)
    nz = 100

    # Size of feature maps in generator
    ngf = 32

    # Size of feature maps in discriminator
    ndf = 32

    # Beta1 hyperparam for Adam optimizers
    beta1 = 0.5

    # iterations of actual training in each Trainable _train
    train_iterations_per_step = 5

    MODEL_PATH = os.path.expanduser("~/.ray/models/mnist_cnn.pt")


    def get_data_loader():
        dataset = dset.MNIST(
            root=dataroot,
            download=True,
            transform=transforms.Compose([
                transforms.Resize(image_size),
                transforms.ToTensor(),
                transforms.Normalize((0.5, ), (0.5, )),
            ]))

        # Create the dataloader
        dataloader = torch.utils.data.DataLoader(
            dataset, batch_size=batch_size, shuffle=True, num_workers=workers)

        return dataloader


    # __GANmodel_begin__
    # custom weights initialization called on netG and netD
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find("Conv") != -1:
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        elif classname.find("BatchNorm") != -1:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)


    # Generator Code
    class Generator(nn.Module):
        def __init__(self):
            super(Generator, self).__init__()
            self.main = nn.Sequential(
                # input is Z, going into a convolution
                nn.ConvTranspose2d(nz, ngf * 4, 4, 1, 0, bias=False),
                nn.BatchNorm2d(ngf * 4),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf * 2),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ngf),
                nn.ReLU(True),
                nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
                nn.Tanh())

        def forward(self, input):
            return self.main(input)


    class Discriminator(nn.Module):
        def __init__(self):
            super(Discriminator, self).__init__()
            self.main = nn.Sequential(
                nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ndf * 2), nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
                nn.BatchNorm2d(ndf * 4), nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 4, 1, 4, 1, 0, bias=False), nn.Sigmoid())

        def forward(self, input):
            return self.main(input)


    # __GANmodel_end__


    # __INCEPTION_SCORE_begin__
    class Net(nn.Module):
        """
        LeNet for MNist classification, used for inception_score
        """

        def __init__(self):
            super(Net, self).__init__()
            self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
            self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
            self.conv2_drop = nn.Dropout2d()
            self.fc1 = nn.Linear(320, 50)
            self.fc2 = nn.Linear(50, 10)

        def forward(self, x):
            x = F.relu(F.max_pool2d(self.conv1(x), 2))
            x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
            x = x.view(-1, 320)
            x = F.relu(self.fc1(x))
            x = F.dropout(x, training=self.training)
            x = self.fc2(x)
            return F.log_softmax(x, dim=1)


    def inception_score(imgs, mnist_model_ref, batch_size=32, splits=1):
        N = len(imgs)
        dtype = torch.FloatTensor
        dataloader = torch.utils.data.DataLoader(imgs, batch_size=batch_size)
        cm = ray.get(mnist_model_ref)  # Get the mnist model from Ray object store.
        up = nn.Upsample(size=(28, 28), mode="bilinear").type(dtype)

        def get_pred(x):
            x = up(x)
            x = cm(x)
            return F.softmax(x).data.cpu().numpy()

        preds = np.zeros((N, 10))
        for i, batch in enumerate(dataloader, 0):
            batch = batch.type(dtype)
            batchv = Variable(batch)
            batch_size_i = batch.size()[0]
            preds[i * batch_size:i * batch_size + batch_size_i] = get_pred(batchv)

        # Now compute the mean kl-div
        split_scores = []
        for k in range(splits):
            part = preds[k * (N // splits):(k + 1) * (N // splits), :]
            py = np.mean(part, axis=0)
            scores = []
            for i in range(part.shape[0]):
                pyx = part[i, :]
                scores.append(entropy(pyx, py))
            split_scores.append(np.exp(np.mean(scores)))

        return np.mean(split_scores), np.std(split_scores)


    # __INCEPTION_SCORE_end__


    def train(netD, netG, optimG, optimD, criterion, dataloader, iteration, device,
              mnist_model_ref):
        real_label = 1
        fake_label = 0

        for i, data in enumerate(dataloader, 0):
            if i >= train_iterations_per_step:
                break

            netD.zero_grad()
            real_cpu = data[0].to(device)
            b_size = real_cpu.size(0)
            label = torch.full(
                (b_size, ), real_label, dtype=torch.float, device=device)
            output = netD(real_cpu).view(-1)
            errD_real = criterion(output, label)
            errD_real.backward()
            D_x = output.mean().item()

            noise = torch.randn(b_size, nz, 1, 1, device=device)
            fake = netG(noise)
            label.fill_(fake_label)
            output = netD(fake.detach()).view(-1)
            errD_fake = criterion(output, label)
            errD_fake.backward()
            D_G_z1 = output.mean().item()
            errD = errD_real + errD_fake
            optimD.step()

            netG.zero_grad()
            label.fill_(real_label)
            output = netD(fake).view(-1)
            errG = criterion(output, label)
            errG.backward()
            D_G_z2 = output.mean().item()
            optimG.step()

            is_score, is_std = inception_score(fake, mnist_model_ref)

            # Output training stats
           # if iteration % 10 == 0:
            #    print("[%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z))"
             #         ": %.4f / %.4f \tInception score: %.4f" %
              #        (iteration, len(dataloader), errD.item(), errG.item(), D_x,
               #        D_G_z1, D_G_z2, is_score))

        return errG.item(), errD.item(), is_score


    def plot_images(dataloader):
        # Plot some training images
        if 1==0:
            real_batch = next(iter(dataloader))
            plt.figure(figsize=(8, 8))
            plt.axis("off")
            plt.title("Original Images")
            plt.imshow(
                np.transpose(
                    vutils.make_grid(real_batch[0][:64], padding=2,
                                     normalize=True).cpu(), (1, 2, 0)))

            plt.show()


    def demo_gan(checkpoint_paths):
        img_list = []
        fixed_noise = torch.randn(64, nz, 1, 1)
        for netG_path in checkpoint_paths:
            loadedG = Generator()
            loadedG.load_state_dict(torch.load(netG_path)["netGmodel"])
            with torch.no_grad():
                fake = loadedG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        fig = plt.figure(figsize=(8, 8))
        plt.axis("off")
        ims = [[plt.imshow(np.transpose(i, (1, 2, 0)), animated=True)]
               for i in img_list]
        ani = animation.ArtistAnimation(
            fig, ims, interval=1000, repeat_delay=1000, blit=True)
        ani.save("./generated" +str(SA)+".gif", writer="imagemagick", dpi=72)
        plt.show()




    # __Trainable_begin__
    class PytorchTrainable(tune.Trainable):
        def setup(self, config):
            use_cuda = config.get("use_gpu") and torch.cuda.is_available()
            self.device = torch.device("cuda" if use_cuda else "cpu")
            self.netD = Discriminator().to(self.device)
            self.netD.apply(weights_init)
            self.netG = Generator().to(self.device)
            self.netG.apply(weights_init)
            self.criterion = nn.BCELoss()    
            self.optimizerD =optim.Adam(
                self.netD.parameters(),
                lr=config.get("lr", 0.01),
                betas=(beta1, 0.999))
            self.optimizerG =optim.Adam(
                self.netG.parameters(),
                lr=config.get("lr", 0.01),
                betas=(beta1, 0.999))

            with FileLock(os.path.expanduser("~/.data.lock")):
                self.dataloader = get_data_loader()
            self.mnist_model_ref = c["mnist_model_ref"]

        def step(self):
            lossG, lossD, is_score = train(self.netD, self.netG, self.optimizerG,
                                           self.optimizerD, self.criterion,
                                           self.dataloader, self._iteration,
                                           self.device, self.mnist_model_ref)
            return {"lossg": lossG, "lossd": lossD, "is_score": 10- is_score}

        def save_checkpoint(self, checkpoint_dir):
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save({
                "netDmodel": self.netD.state_dict(),
                "netGmodel": self.netG.state_dict(),
                "optimD": self.optimizerD.state_dict(),
                "optimG": self.optimizerG.state_dict(),
            }, path)

            return checkpoint_dir

        def load_checkpoint(self, checkpoint_dir):
            path = os.path.join(checkpoint_dir, "checkpoint")
            checkpoint = torch.load(path)
            self.netD.load_state_dict(checkpoint["netDmodel"])
            self.netG.load_state_dict(checkpoint["netGmodel"])
            self.optimizerD.load_state_dict(checkpoint["optimD"])
            self.optimizerG.load_state_dict(checkpoint["optimG"])

        def reset_config(self, new_config):
            if "netD_lr" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["lr"] = 10**-(new_config["netD_lr"])
            if "netG_lr" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["lr"] = 10**-(new_config["netG_lr"])
            if "netD_B" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["betas"] = (10**-(new_config["netD_B"]),0.999)
            if "netG_B" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["betas"] = (10**-(new_config["netG_B"]),0.999)
            if "weight_decay1" in new_config:
                for param_group in self.optimizerD.param_groups:
                    param_group["weight_decay"] = 10**-(new_config["weight_decay1"])
            if "weight_decay2" in new_config:
                for param_group in self.optimizerG.param_groups:
                    param_group["weight_decay"] = 10**-(new_config["weight_decay2"])
            self.config = new_config
            return True

        def _export_model(self, export_formats, export_dir):
            if export_formats == [ExportFormat.MODEL]:
                path = os.path.join(export_dir, "exported_models")
                torch.save({
                    "netDmodel": self.netD.state_dict(),
                    "netGmodel": self.netG.state_dict()
                }, path)
                return {ExportFormat.MODEL: path}
            else:
                raise ValueError("unexpected formats: " + str(export_formats))



    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--smoke-test", action="store_true", help="Finish quickly for testing")
    args, _ = parser.parse_known_args()
    import urllib.request
    # Download a pre-trained MNIST model for inception score calculation.
    # This is a tiny model (<100kb).
    if not os.path.exists(MODEL_PATH):
        print("downloading model")
        os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
        urllib.request.urlretrieve(
            "https://github.com/ray-project/ray/raw/master/python/ray/tune/"
            "examples/pbt_dcgan_mnist/mnist_cnn.pt", MODEL_PATH)

    dataloader = get_data_loader()
    if not args.smoke_test:
        plot_images(dataloader)

    # load the pretrained mnist classification model for inception_score
    mnist_cnn = Net()
    mnist_cnn.load_state_dict(torch.load(MODEL_PATH))
    mnist_cnn.eval()
    mnist_model_ref = ray.put(mnist_cnn)

    # __tune_begin__
    scheduler = PopulationBasedTraining(
        time_attr="training_iteration",
        perturbation_interval=5,
        hyperparam_mutations={
            # distribution for resampling
            "netG_lr": lambda: np.random.uniform(1, 9),
            "netD_lr": lambda: np.random.uniform(1, 9),
            "netD_B": lambda: np.random.uniform(0, 2),
            "netD_B": lambda: np.random.uniform(0, 2),
            "weight_decay1":lambda: np.random.uniform(3, 8),
            "weight_decay2":lambda: np.random.uniform(3, 8)
        })
    c={"mnist_model_ref" : mnist_model_ref}


    experiment_metrics= dict(metric="is_score",
        mode="min")

 
    
    if(SA==0):
        algo = HyperOptSearch(**experiment_metrics)
        name="hypher"

    if(SA==1):
        algo =   BayesOptSearch(**experiment_metrics) 
        name="Bayes"
        
    if(SA==2):
        algo = AxSearch(
            max_concurrent=2, #was working with 2
            **experiment_metrics
        )
        name="AX"

        
        
    if(SA==3):
        algo = NevergradSearch(
            optimizer=ng.optimizers.CMA,**experiment_metrics
            # space=space,  # If you want to set the space manually
            )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="NG"
     
    if(SA==4):
        algo = NevergradSearch(
            optimizer=ng.optimizers.TwoPointsDE,**experiment_metrics
            # space=space,  # If you want to set the space manually
            )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="NG2DE"

        
        
    if(SA==5):
        algo = NevergradSearch(
        optimizer=ng.optimizers.RandomSearch,**experiment_metrics
        # space=space,  # If you want to set the space manually
        )
        algo = ConcurrencyLimiter(algo, max_concurrent=8)
        name="random"
                
    if(SA==6):
        dim_dict = {
        "netG_lr": (ValueType.CONTINUOUS, [0, 0.1], 1e-2),
        "netD_lr": (ValueType.CONTINUOUS, [0, 0.1], 1e-2)
        }
        algo = ZOOptSearch(
        algo="Asracos",  # only support Asracos currently
        #dim_dict=dim_dict,
      #  dim_dict=dim_dict,

        budget=100,
            **experiment_metrics
        #dim_dict=dim_dict,
       #     **zoopt_search_config,
        )
        name="zoo"


  #  if(SA!=4):
   #     scheduler = AsyncHyperBandScheduler(**experiment_metrics)
        
        
    os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)

    tune_kwargs = {
    "num_samples": 128 if args.smoke_test else 128,
      "stop":{
            "training_iteration": 200,
        },  

    "config": {
     "lr1":  tune.uniform(2, 5) #tune.uniform(1e-4, 0.1 ),#,1e-4), #*10
    , "lr2":  tune.uniform(2, 5) #tune.uniform(1e-4, 0.1 ),#,1e-4), #*10
    ,     "weight_decay1":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0
    ,     "weight_decay2":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0    
    ,     "beta1":2 #tune.uniform(1, 5),#,1e-4), #*10 et 0
     ,    "beta2":1 #tune.uniform(1, 5),#,1e-4), #*10 et 0
      ,  "adam1":0#tune.uniform(0,1),
      ,  "adam2":0#tune.uniform(0,1),
        }
    }
    def trial_name_id(trial):
        return f"{trial.trainable_name}_{trial.trial_id}"

    analysis = tune.run(
    PytorchTrainable,
    name=name,
    scheduler=scheduler,
    reuse_actors=True,
    search_alg=algo,
    verbose=0,
    checkpoint_at_end=True,
    num_samples=64,
   # export_formats=[ExportFormat.MODEL],
        config =     {
            "netG_lr": tune.uniform(1, 9),
           "netD_lr": tune.uniform(1, 9),
            "netG_B": tune.uniform(0, 2),
           "netD_B": tune.uniform(0, 2),
            "weight_decay1":tune.uniform(3, 8)#tune.uniform(1, 5)#,1e-4), #*10 et 0
    ,     "weight_decay2":tune.uniform(3, 8)
        },      stop={
            "training_iteration": 100,
        },        metric="is_score",
        mode="min",
                  loggers=[TestLogger])

    all_trials = analysis.trials
    checkpoint_paths = [
        os.path.join(analysis.get_best_checkpoint(t), "checkpoint")
        for t in all_trials
    ]
    demo_gan(checkpoint_paths)

# %%
ray.init()
# Out:
# 2020-11-28 21:13:26,427	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '192.168.1.34',
#  'raylet_ip_address': '192.168.1.34',
#  'redis_address': '192.168.1.34:6379',
#  'object_store_address': '/tmp/ray/session_2020-11-28_21-13-25_894152_23309/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-11-28_21-13-25_894152_23309/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2020-11-28_21-13-25_894152_23309',
#  'metrics_export_port': 58786}

# %%
from ray.tune.logger import *
supernombre=0;
class TestLogger(tune.logger.Logger):
    def _init(self):
        progress_file = os.path.join("/home/antoine/Projet/NovelTuning/", str(supernombre)+".csv")
        self._continuing = os.path.exists(progress_file)
        self._file = open(progress_file, "a")
        self._csv_out = None
    def on_result(self, result):
        tmp = result.copy()
        #if "done" in tmp:
         #   if(tmp["done"] != True):

        if "config" in tmp:
            del tmp["config"]
        result = flatten_dict(tmp, delimiter="/")
        if self._csv_out is None:
            self._csv_out = csv.DictWriter(self._file, result.keys())
            if not self._continuing:
                self._csv_out.writeheader()
        self._csv_out.writerow(
            {k: v
             for k, v in result.items() if k in self._csv_out.fieldnames})
        self._file.flush()
                   
            
GAN_MNIST(0)
# Out:
# == Status ==<br>Memory usage on this node: 8.7/15.6 GiB<br>PopulationBasedTraining: 0 checkpoints, 0 perturbs<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/6.74 GiB heap, 0.0/2.29 GiB objects<br>Result logdir: /home/antoine/ray_results/hypher<br>Number of trials: 10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status  </th><th>loc  </th><th style="text-align: right;">   netD_B</th><th style="text-align: right;">  netD_lr</th><th style="text-align: right;">  netG_B</th><th style="text-align: right;">  netG_lr</th><th style="text-align: right;">  weight_decay1</th><th style="text-align: right;">  weight_decay2</th></tr>
# </thead>
# <tbody>
# <tr><td>PytorchTrainable_a0b0a622</td><td>RUNNING </td><td>     </td><td style="text-align: right;">1.32812  </td><td style="text-align: right;">  6.76701</td><td style="text-align: right;">1.07561 </td><td style="text-align: right;">  7.29959</td><td style="text-align: right;">        5.12812</td><td style="text-align: right;">        7.36102</td></tr>
# <tr><td>PytorchTrainable_a0b1606c</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.708011 </td><td style="text-align: right;">  1.71755</td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  6.98682</td><td style="text-align: right;">        7.1387 </td><td style="text-align: right;">        7.87386</td></tr>
# <tr><td>PytorchTrainable_a0b1ff86</td><td>PENDING </td><td>     </td><td style="text-align: right;">1.42236  </td><td style="text-align: right;">  5.82338</td><td style="text-align: right;">1.38674 </td><td style="text-align: right;">  4.82075</td><td style="text-align: right;">        3.19317</td><td style="text-align: right;">        3.89388</td></tr>
# <tr><td>PytorchTrainable_a0b2c3e4</td><td>PENDING </td><td>     </td><td style="text-align: right;">1.33221  </td><td style="text-align: right;">  6.09612</td><td style="text-align: right;">0.725695</td><td style="text-align: right;">  3.16014</td><td style="text-align: right;">        7.09062</td><td style="text-align: right;">        7.58791</td></tr>
# <tr><td>PytorchTrainable_a0b36696</td><td>PENDING </td><td>     </td><td style="text-align: right;">1.4897   </td><td style="text-align: right;">  5.26921</td><td style="text-align: right;">1.82276 </td><td style="text-align: right;">  6.74883</td><td style="text-align: right;">        7.89753</td><td style="text-align: right;">        4.17182</td></tr>
# <tr><td>PytorchTrainable_a0b40678</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.440324 </td><td style="text-align: right;">  3.31867</td><td style="text-align: right;">0.669387</td><td style="text-align: right;">  2.15974</td><td style="text-align: right;">        6.32713</td><td style="text-align: right;">        5.08041</td></tr>
# <tr><td>PytorchTrainable_a0b49ed0</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.627058 </td><td style="text-align: right;">  5.57192</td><td style="text-align: right;">1.63065 </td><td style="text-align: right;">  8.61507</td><td style="text-align: right;">        3.85455</td><td style="text-align: right;">        5.83933</td></tr>
# <tr><td>PytorchTrainable_a0b54b3c</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.0643337</td><td style="text-align: right;">  2.29236</td><td style="text-align: right;">1.339   </td><td style="text-align: right;">  4.0866 </td><td style="text-align: right;">        3.03734</td><td style="text-align: right;">        5.82393</td></tr>
# <tr><td>PytorchTrainable_a0b606bc</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.971504 </td><td style="text-align: right;">  6.99762</td><td style="text-align: right;">1.67226 </td><td style="text-align: right;">  7.58656</td><td style="text-align: right;">        6.85254</td><td style="text-align: right;">        6.95352</td></tr>
# <tr><td>PytorchTrainable_a0b6ae00</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.475011 </td><td style="text-align: right;">  1.82734</td><td style="text-align: right;">1.81663 </td><td style="text-align: right;">  7.11796</td><td style="text-align: right;">        3.45377</td><td style="text-align: right;">        7.99447</td></tr>
# </tbody>
# </table><br><br>
# (pid=7794) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7794)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7794) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7796) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7796)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7796) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7792) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7792)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7792) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7790) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7790)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7790) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7802) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7802)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7802) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7800) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7800)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7800) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7807) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7807)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7807) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=7798) /home/antoine/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# (pid=7798)   "See the documentation of nn.Upsample for details.".format(mode))
# (pid=7798) /home/antoine/anaconda3/lib/python3.7/site-packages/ray/workers/default_worker.py:252: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Result for PytorchTrainable_a0b40678:
#   date: 2020-11-28_22-42-40
#   done: false
#   experiment_id: c7b44d840cd746a2ab620fcf360cd733
#   experiment_tag: 6_netD_B=0.44032,netD_lr=3.3187,netG_B=0.66939,netG_lr=2.1597,weight_decay1=6.3271,weight_decay2=5.0804
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0016171794686932
#   iterations_since_restore: 1
#   lossd: 1.158613681793213
#   lossg: 8.62171459197998
#   node_ip: 192.168.1.34
#   pid: 7794
#   time_since_restore: 2.4450573921203613
#   time_this_iter_s: 2.4450573921203613
#   time_total_s: 2.4450573921203613
#   timestamp: 1606599760
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b40678
# == Status ==<br>Memory usage on this node: 10.8/15.6 GiB<br>PopulationBasedTraining: 0 checkpoints, 0 perturbs<br>Resources requested: 8/8 CPUs, 0/0 GPUs, 0.0/6.74 GiB heap, 0.0/2.29 GiB objects<br>Result logdir: /home/antoine/ray_results/hypher<br>Number of trials: 10 (2 PENDING, 8 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status  </th><th>lo
td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>PytorchTrainable_a0b6ae00</td><td>PENDING </td><td>                 </td><td style="text-align: right;">0.475011 </td><td style="text-align: right;">  1.82734</td><td style="text-align: right;">1.81663 </td><td style="text-align: right;">  7.11796</td><td style="text-align: right;">        3.45377</td><td style="text-align: right;">        7.99447</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for PytorchTrainable_a0b1606c:
#   date: 2020-11-28_22-42-40
#   done: false
#   experiment_id: 951879e1c2bb4a2983bfccecd9205201
#   experiment_tag: 2_netD_B=0.70801,netD_lr=1.7176,netG_B=0.19516,netG_lr=6.9868,weight_decay1=7.1387,weight_decay2=7.8739
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000000000004
#   iterations_since_restore: 1
#   lossd: 7.460464954376221
#   lossg: 10.719350814819336
#   node_ip: 192.168.1.34
#   pid: 7796
#   time_since_restore: 2.5763461589813232
#   time_this_iter_s: 2.5763461589813232
#   time_total_s: 2.5763461589813232
#   timestamp: 1606599760
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b1606c
#
# Result for PytorchTrainable_a0b1ff86:
#   date: 2020-11-28_22-42-40
#   done: false
#   experiment_id: 1af2897ce5ac4c0d9022a9dc9dd20328
#   experiment_tag: 3_netD_B=1.4224,netD_lr=5.8234,netG_B=1.3867,netG_lr=4.8207,weight_decay1=3.1932,weight_decay2=3.8939
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000000000004
#   iterations_since_restore: 1
#   lossd: 1.5014561414718628
#   lossg: 5.438760757446289
#   node_ip: 192.168.1.34
#   pid: 7792
#   time_since_restore: 2.546977996826172
#   time_this_iter_s: 2.546977996826172
#   time_total_s: 2.546977996826172
#   timestamp: 1606599760
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b1ff86
#
# Result for PytorchTrainable_a0b0a622:
#   date: 2020-11-28_22-42-40
#   done: false
#   experiment_id: d03a4ded2f444262a35d6ccb542da337
#   experiment_tag: 1_netD_B=1.3281,netD_lr=6.767,netG_B=1.0756,netG_lr=7.2996,weight_decay1=5.1281,weight_decay2=7.361
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000000000004
#   iterations_since_restore: 1
#   lossd: 0.4814017117023468
#   lossg: 5.191094398498535
#   node_ip: 192.168.1.34
#   pid: 7790
#   time_since_restore: 2.6095571517944336
#   time_this_iter_s: 2.6095571517944336
#   time_total_s: 2.6095571517944336
#   timestamp: 1606599760
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b0a622
#
# Result for PytorchTrainable_a0b2c3e4:
#   date: 2020-11-28_22-42-41
#   done: false
#   experiment_id: f0554ae971bd4759b72342888950a81a
#   experiment_tag: 4_netD_B=1.3322,netD_lr=6.0961,netG_B=0.7257,netG_lr=3.1601,weight_decay1=7.0906,weight_decay2=7.5879
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000000000004
#   iterations_since_restore: 1
#   lossd: 0.09616798907518387
#   lossg: 5.51251220703125
#   node_ip: 192.168.1.34
#   pid: 7798
#   time_since_restore: 2.53615403175354
#   time_this_iter_s: 2.53615403175354
#   time_total_s: 2.53615403175354
#   timestamp: 1606599761
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b2c3e4
#
# Result for PytorchTrainable_a0b36696:
#   date: 2020-11-28_22-42-41
#   done: false
#   experiment_id: 90e2308a95bd4c278afd7d96355f78b0
#   experiment_tag: 5_netD_B=1.4897,netD_lr=5.2692,netG_B=1.8228,netG_lr=6.7488,weight_decay1=7.8975,weight_decay2=4.1718
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000000000004
#   iterations_since_restore: 1
#   lossd: 1.7564013004302979
#   lossg: 6.133923530578613
#   node_ip: 192.168.1.34
#   pid: 7802
#   time_since_restore: 2.748206853866577
#   time_this_iter_s: 2.748206853866577
#   time_total_s: 2.748206853866577
#   timestamp: 1606599761
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b36696
#
# Result for PytorchTrainable_a0b54b3c:
#   date: 2020-11-28_22-42-41
#   done: false
#   experiment_id: f052b8aaf1c1440db30bcf950f7c65d3
#   experiment_tag: 8_netD_B=0.064334,netD_lr=2.2924,netG_B=1.339,netG_lr=4.0866,weight_decay1=3.0373,weight_decay2=5.8239
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.000000097222974
#   iterations_since_restore: 1
#   lossd: 5.165595531463623
#   lossg: 6.055197238922119
#   node_ip: 192.168.1.34
#   pid: 7807
#   time_since_restore: 2.6359541416168213
#   time_this_iter_s: 2.6359541416168213
#   time_total_s: 2.6359541416168213
#   timestamp: 1606599761
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b54b3c
#
# Result for PytorchTrainable_a0b49ed0:
#   date: 2020-11-28_22-42-41
#   done: false
#   experiment_id: 46eb010d9e3b47c6be39651c0492da79
#   experiment_tag: 7_netD_B=0.62706,netD_lr=5.5719,netG_B=1.6307,netG_lr=8.6151,weight_decay1=3.8545,weight_decay2=5.8393
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0000000013412873
#   iterations_since_restore: 1
#   lossd: 3.6288304328918457
#   lossg: 9.719634056091309
#   node_ip: 192.168.1.34
#   pid: 7800
#   time_since_restore: 2.835834503173828
#   time_this_iter_s: 2.835834503173828
#   time_total_s: 2.835834503173828
#   timestamp: 1606599761
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a0b49ed0
# == Status ==<br>Memory usage on this node: 10.9/15.6 GiB<br>PopulationBasedTraining: 0 checkpoints, 0 perturbs<br>Resources requested: 8/8 CPUs, 0/0 GPUs, 0.0/6.74 GiB heap, 0.0/2.29 GiB objects<br>Result logdir: /home/antoine/ray_results/hypher<br>Number of trials: 10 (2 PENDING, 8 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status  </th><th>loc              </th><th style="text-align: right;">   netD_B</th><th style="text-align: right;">  netD_lr</th><th style="text-align: right;">  netG_B</th><th style="text-align: right;">  netG_lr</th><th style="text-align: right;">  weight_decay1</th><th style="text-align: right;">  weight_decay2</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  lossg</th><th style="text-align: right;">   lossd</th><th style="text-align: right;">  is_score</th></tr>
# </thead>
# <tbody>
# <tr><td>PytorchTrainable_a0b0a622</td><td>RUNNING </td><td>192.168.1.34:7790</td><td style="text-align: right;">1.32812  </td><td style="text-align: right;">  6.76701</td><td style="text-align: right;">1.07561 </td><td style="text-align: right;">  7.29959</td><td style="text-align: right;">        5.12812</td><td style="text-align: right;">        7.36102</td><td style="text-align: right;">     2</td><td style="text-align: right;">         5.15402</td><td style="text-align: right;">4.05195</td><td style="text-align: right;">1.04275 </td><td style="text-align: right;">   1.00452</td></tr>
# <tr><td>PytorchTrainable_a0b1606c</td><td>RUNNING </td><td>192.168.1.34:7796</td><td style="text-align: right;">0.708011 </td><td style="text-align: right;">  1.71755</td><td style="text-align: right;">0.195163</td><td style="text-align: right;">
# <tr><td>PytorchTrainable_a0b606bc</td><td>PENDING </td><td>                 </td><td style="text-align: right;">0.971504 </td><td style="text-align: right;">  6.99762</td><td style="text-align: right;">1.67226 </td><td style="text-align: right;">  7.58656</td><td style="text-align: right;">        6.85254</td><td style="text-align: right;">        6.95352</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>PytorchTrainable_a0b6ae00</td><td>PENDING </td><td>                 </td><td style="text-align: right;">0.475011 </td><td style="text-align: right;">  1.82734</td><td style="text-align: right;">1.81663 </td><td style="text-align: right;">  7.11796</td><td style="text-align: right;">        3.45377</td><td style="text-align: right;">        7.99447</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for PytorchTrainable_a0b1606c:
#   date: 2020-11-28_22-42-45
#   done: false
#   experiment_id: 951879e1c2bb4a2983bfccecd9205201
#   experiment_tag: 2_netD_B=0.70801,netD_lr=1.7176,netG_B=0.19516,netG_lr=6.9868,weight_decay1=7.1387,weight_decay2=7.8739
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.023975960326913
#   iterations_since_restore: 3
#   lossd: 1.265509009361267
#   lossg: 3.046955108642578
#   node_ip: 192.168.1.34
#   pid: 7796
#   time_since_restore: 7.775819540023804
#   time_this_iter_s: 2.7050364017486572
#   time_total_s: 7.775819540023804
#   timestamp: 1606599765
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b1606c
#
# Result for PytorchTrainable_a0b40678:
#   date: 2020-11-28_22-42-45
#   done: false
#   experiment_id: c7b44d840cd746a2ab620fcf360cd733
#   experiment_tag: 6_netD_B=0.44032,netD_lr=3.3187,netG_B=0.66939,netG_lr=2.1597,weight_decay1=6.3271,weight_decay2=5.0804
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0075156566141834
#   iterations_since_restore: 3
#   lossd: 2.3319294452667236
#   lossg: 9.789691925048828
#   node_ip: 192.168.1.34
#   pid: 7794
#   time_since_restore: 7.743377923965454
#   time_this_iter_s: 2.6407878398895264
#   time_total_s: 7.743377923965454
#   timestamp: 1606599765
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b40678
#
# Result for PytorchTrainable_a0b0a622:
#   date: 2020-11-28_22-42-46
#   done: false
#   experiment_id: d03a4ded2f444262a35d6ccb542da337
#   experiment_tag: 1_netD_B=1.3281,netD_lr=6.767,netG_B=1.0756,netG_lr=7.2996,weight_decay1=5.1281,weight_decay2=7.361
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0441866367819097
#   iterations_since_restore: 3
#   lossd: 2.041992664337158
#   lossg: 5.191807746887207
#   node_ip: 192.168.1.34
#   pid: 7790
#   time_since_restore: 7.819164991378784
#   time_this_iter_s: 2.6651418209075928
#   time_total_s: 7.819164991378784
#   timestamp: 1606599766
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b0a622
#
# Result for PytorchTrainable_a0b54b3c:
#   date: 2020-11-28_22-42-46
#   done: false
#   experiment_id: f052b8aaf1c1440db30bcf950f7c65d3
#   experiment_tag: 8_netD_B=0.064334,netD_lr=2.2924,netG_B=1.339,netG_lr=4.0866,weight_decay1=3.0373,weight_decay2=5.8239
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0028428644796423
#   iterations_since_restore: 3
#   lossd: 1.6950854063034058
#   lossg: 0.7990986108779907
#   node_ip: 192.168.1.34
#   pid: 7807
#   time_since_restore: 7.785449981689453
#   time_this_iter_s: 2.6026408672332764
#   time_total_s: 7.785449981689453
#   timestamp: 1606599766
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b54b3c
#
# Result for PytorchTrainable_a0b36696:
#   date: 2020-11-28_22-42-46
#   done: false
#   experiment_id: 90e2308a95bd4c278afd7d96355f78b0
#   experiment_tag: 5_netD_B=1.4897,netD_lr=5.2692,netG_B=1.8228,netG_lr=6.7488,weight_decay1=7.8975,weight_decay2=4.1718
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0228175334239729
#   iterations_since_restore: 3
#   lossd: 1.346701741218567
#   lossg: 2.8359475135803223
#   node_ip: 192.168.1.34
#   pid: 7802
#   time_since_restore: 8.187506198883057
#   time_this_iter_s: 2.902780771255493
#   time_total_s: 8.187506198883057
#   timestamp: 1606599766
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b36696
#
# Result for PytorchTrainable_a0b49ed0:
#   date: 2020-11-28_22-42-46
#   done: false
#   experiment_id: 46eb010d9e3b47c6be39651c0492da79
#   experiment_tag: 7_netD_B=0.62706,netD_lr=5.5719,netG_B=1.6307,netG_lr=8.6151,weight_decay1=3.8545,weight_decay2=5.8393
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0066153582672357
#   iterations_since_restore: 3
#   lossd: 1.2145041227340698
#   lossg: 3.546443223953247
#   node_ip: 192.168.1.34
#   pid: 7800
#   time_since_restore: 8.37156367301941
#   time_this_iter_s: 2.8409371376037598
#   time_total_s: 8.37156367301941
#   timestamp: 1606599766
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b49ed0
#
# Result for PytorchTrainable_a0b2c3e4:
#   date: 2020-11-28_22-42-46
#   done: false
#   experiment_id: f0554ae971bd4759b72342888950a81a
#   experiment_tag: 4_netD_B=1.3322,netD_lr=6.0961,netG_B=0.7257,netG_lr=3.1601,weight_decay1=7.0906,weight_decay2=7.5879
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.0021464209790243
#   iterations_since_restore: 3
#   lossd: 2.389698028564453
#   lossg: 2.9006361961364746
#   node_ip: 192.168.1.34
#   pid: 7798
#   time_since_restore: 8.40889286994934
#   time_this_iter_s: 3.1335394382476807
#   time_total_s: 8.40889286994934
#   timestamp: 1606599766
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: a0b2c3e4
#
# Result for PytorchTrainable_a0b1ff86:
#   date: 2020-11-28_22-42-48
#   done: false
#   experiment_id: 1af2897ce5ac4c0d9022a9dc9dd20328
#   experiment_tag: 3_netD_B=1.4224,netD_lr=5.8234,netG_B=1.3867,netG_lr=4.8207,weight_decay1=3.1932,weight_decay2=3.8939
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.248870792071803
#   iterations_since_restore: 4
#   lossd: 1.539294719696045
#   lossg: 1.1991246938705444
#   node_ip: 192.168.1.34
#   pid: 7792
#   time_since_restore: 10.671749353408813
#   time_this_iter_s: 3.3181493282318115
#   time_total_s: 10.671749353408813
#   timestamp: 1606599768
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: a0b1ff86
# == Status ==<br>Memory usage on this node: 10.7/15.6 GiB<br>PopulationBasedTraining: 0 checkpoints, 0 perturbs<br>Resources requested: 8/8 CPUs, 0/0 GPUs, 0.0/6.74 GiB heap, 0.0/2.29 GiB objects<br>Result logdir: /home/antoine/ray_results/hypher<br>Number of trials: 10 (2 PENDING, 8 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status  </th><th>lo
INFO trainable.py:489 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 14.677467823028564, '_episodes_total': None}
# Result for PytorchTrainable_a0b54b3c:
#   date: 2020-11-28_22-42-53
#   done: false
#   experiment_id: f052b8aaf1c1440db30bcf950f7c65d3
#   experiment_tag: 8_netD_B=0.064334,netD_lr=2.2924,netG_B=1.339,netG_lr=4.0866,weight_decay1=3.0373,weight_decay2=5.8239
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.093260574298756
#   iterations_since_restore: 5
#   lossd: 1.5609725713729858
#   lossg: 0.8873918652534485
#   node_ip: 192.168.1.34
#   pid: 7807
#   time_since_restore: 14.871908903121948
#   time_this_iter_s: 3.570845127105713
#   time_total_s: 14.871908903121948
#   timestamp: 1606599773
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: a0b54b3c
#
# Result for PytorchTrainable_a0b1606c:
#   date: 2020-11-28_22-42-53
#   done: false
#   experiment_id: 951879e1c2bb4a2983bfccecd9205201
#   experiment_tag: 2_netD_B=0.70801,netD_lr=1.7176,netG_B=0.19516,netG_lr=6.9868,weight_decay1=7.1387,weight_decay2=7.8739
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.3094965637522236
#   iterations_since_restore: 5
#   lossd: 2.4136366844177246
#   lossg: 3.0803964138031006
#   node_ip: 192.168.1.34
#   pid: 7796
#   time_since_restore: 15.33476710319519
#   time_this_iter_s: 4.068440914154053
#   time_total_s: 15.33476710319519
#   timestamp: 1606599773
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: a0b1606c
#
# Result for PytorchTrainable_a0b0a622:
#   date: 2020-11-28_22-42-53
#   done: false
#   experiment_id: d03a4ded2f444262a35d6ccb542da337
#   experiment_tag: 1_netD_B=1.3281,netD_lr=6.767,netG_B=1.0756,netG_lr=7.2996,weight_decay1=5.1281,weight_decay2=7.361
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.4101863323203818
#   iterations_since_restore: 5
#   lossd: 1.156972050666809
#   lossg: 3.3487210273742676
#   node_ip: 192.168.1.34
#   pid: 7790
#   time_since_restore: 15.362852811813354
#   time_this_iter_s: 3.9561688899993896
#   time_total_s: 15.362852811813354
#   timestamp: 1606599773
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: a0b0a622
# (pid=7796) 2020-11-28 22:42:53,792	INFO trainable.py:482 -- Restored on 192.168.1.34 from checkpoint: /home/antoine/ray_results/hypher/PytorchTrainable_a0b1606c_2_netD_B=0.70801,netD_lr=1.7176,netG_B=0.19516,netG_lr=6.9868,weight_decay1=7.1387,weight_decay2=7.8739_2020-11-28_22-42-35/tmpahkbv5xfrestore_from_object/./
# (pid=7796) 2020-11-28 22:42:53,792	INFO trainable.py:489 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 15.33476710319519, '_episodes_total': None}
# (pid=7790) 2020-11-28 22:42:53,942	INFO trainable.py:482 -- Restored on 192.168.1.34 from checkpoint: /home/antoine/ray_results/hypher/PytorchTrainable_a0b0a622_1_netD_B=1.3281,netD_lr=6.767,netG_B=1.0756,netG_lr=7.2996,weight_decay1=5.1281,weight_decay2=7.361_2020-11-28_22-42-35/tmp8d1fjo6yrestore_from_object/./
# (pid=7790) 2020-11-28 22:42:53,943	INFO trainable.py:489 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 15.362852811813354, '_episodes_total': None}
# Result for PytorchTrainable_a0b36696:
#   date: 2020-11-28_22-42-54
#   done: false
#   experiment_id: 90e2308a95bd4c278afd7d96355f78b0
#   experiment_tag: 5_netD_B=1.4897,netD_lr=5.2692,netG_B=1.8228,netG_lr=6.7488,weight_decay1=7.8975,weight_decay2=4.1718
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.1278294879371142
#   iterations_since_restore: 5
#   lossd: 1.5315361022949219
#   lossg: 6.216468811035156
#   node_ip: 192.168.1.34
#   pid: 7802
#   time_since_restore: 15.786181926727295
#   time_this_iter_s: 3.457089424133301
#   time_total_s: 15.786181926727295
#   timestamp: 1606599774
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: a0b36696
#
# Result for PytorchTrainable_a0b2c3e4:
#   date: 2020-11-28_22-42-54
#   done: false
#   experiment_id: f0554ae971bd4759b72342888950a81a
#   experiment_tag: 4_netD_B=1.3322,netD_lr=6.0961,netG_B=0.7257,netG_lr=3.1601,weight_decay1=7.0906,weight_decay2=7.5879
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 1.1441185569205783
#   iterations_since_restore: 5
#   lossd: 0.6139123439788818
#   lossg: 3.346825122833252
#   node_ip: 192.168.1.34
#   pid: 7798
#   time_since_restore: 15.668657779693604
#   time_this_iter_s: 3.5303497314453125
#   time_total_s: 15.668657779693604
#   timestamp: 1606599774
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: a0b2c3e4
# (pid=7802) 2020-11-28 22:42:54,304	INFO trainable.py:482 -- Restored on 192.168.1.34 from checkpoint: /home/antoine/ray_results/hypher/PytorchTrainable_a0b36696_5_netD_B=1.4897,netD_lr=5.2692,netG_B=1.8228,netG_lr=6.7488,weight_decay1=7.8975,weight_decay2=4.1718_2020-11-28_22-42-35/tmp_itke_vorestore_from_object/./
# (pid=7802) 2020-11-28 22:42:54,304	INFO trainable.py:489 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 15.786181926727295, '_episodes_total': None}
# (pid=7798) 2020-11-28 22:42:54,457	INFO trainable.py:482 -- Restored on 192.168.1.34 from checkpoint: /home/antoine/ray_results/hypher/PytorchTrainable_a0b2c3e4_4_netD_B=1.3322,netD_lr=6.0961,netG_B=0.7257,netG_lr=3.1601,weight_decay1=7.0906,weight_decay2=7.5879_2020-11-28_22-42-35/tmp1ptu1_gcrestore_from_object/./
# (pid=7798) 2020-11-28 22:42:54,457	INFO trainable.py:489 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 15.668657779693604, '_episodes_total': None}
# 2020-11-28 22:42:54,601	INFO pbt.py:502 -- [exploit] transferring weights from trial PytorchTrainable_a0b0a622 (score 1.4101863323203818) -> PytorchTrainable_a0b49ed0 (score 1.052296388147668)
# 2020-11-28 22:42:54,602	INFO pbt.py:514 -- [explore] perturbed config from {'netG_lr': 7.299590168630023, 'netD_lr': 6.767011548978059, 'netD_B': 1.3281183270969528, 'weight_decay1': 5.128120481939971, 'weight_decay2': 7.361016350863003} -> {'netG_lr': 3.6962196799391718, 'netD_lr': 8.12041385877367, 'netD_B': 1.5937419925163432, 'weight_decay1': 6.153744578327965, 'weight_decay2': 8.833219621035603}
# ...
# <tr><td>PytorchTrainable_a0b1ff86</td><td>TERMINATED</td><td>                 </td><td style="text-align: right;">1.91605 </td><td style="text-align: right;">  3.17774</td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  1
td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  1.55556</td><td style="text-align: right;">        3.23372</td><td style="text-align: right;">        9.44647</td><td style="text-align: right;">   198</td><td style="text-align: right;">         722.009</td><td style="text-align: right;">1.80892 </td><td style="text-align: right;">1.26736 </td><td style="text-align: right;">   5.44561</td></tr>
# </tbody>
# </table><br><br>
# Result for PytorchTrainable_a0b606bc:
#   date: 2020-11-28_22-59-30
#   done: true
#   experiment_id: 951879e1c2bb4a2983bfccecd9205201
#   experiment_tag: 9_netD_B=0.9715,netD_lr=6.9976,netG_B=1.6723,netG_lr=7.5866,weight_decay1=6.8525,weight_decay2=6.9535@perturbed[netD_B=1.2343,netD_lr=3.3101,netG_lr=1.3503,weight_decay1=4.2106,weight_decay2=7.8172]
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 5.817229589332432
#   iterations_since_restore: 5
#   lossd: 1.1272614002227783
#   lossg: 1.5361697673797607
#   node_ip: 192.168.1.34
#   pid: 7798
#   time_since_restore: 18.04721426963806
#   time_this_iter_s: 2.1976566314697266
#   time_total_s: 732.2890927791595
#   timestamp: 1606600770
#   timesteps_since_restore: 0
#   training_iteration: 200
#   trial_id: a0b606bc
#
# Result for PytorchTrainable_a0b6ae00:
#   date: 2020-11-28_22-59-31
#   done: true
#   experiment_id: 951879e1c2bb4a2983bfccecd9205201
#   experiment_tag: 10_netD_B=0.47501,netD_lr=1.8273,netG_B=1.8166,netG_lr=7.118,weight_decay1=3.4538,weight_decay2=7.9945@perturbed[netD_B=1.5328,netD_lr=2.5422,netG_lr=1.5556,weight_decay1=3.2337,weight_decay2=9.4465]
#   hostname: antoine-HP-Spectre-Laptop-13-af0xx
#   is_score: 5.4413143290683
#   iterations_since_restore: 5
#   lossd: 1.2934719324111938
#   lossg: 2.1765055656433105
#   node_ip: 192.168.1.34
#   pid: 7899
#   time_since_restore: 14.12091612815857
#   time_this_iter_s: 1.3177704811096191
#   time_total_s: 725.716343164444
#   timestamp: 1606600771
#   timesteps_since_restore: 0
#   training_iteration: 200
#   trial_id: a0b6ae00
# == Status ==<br>Memory usage on this node: 8.8/15.6 GiB<br>PopulationBasedTraining: 145 checkpoints, 95 perturbs<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/6.74 GiB heap, 0.0/2.29 GiB objects<br>Result logdir: /home/antoine/ray_results/hypher<br>Number of trials: 10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc  </th><th style="text-align: right;">  netD_B</th><th style="text-align: right;">  netD_lr</th><th style="text-align: right;">  netG_B</th><th style="text-align: right;">  netG_lr</th><th style="text-align: right;">  weight_decay1</th><th style="text-align: right;">  weight_decay2</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   lossg</th><th style="text-align: right;">  lossd</th><th style="text-align: right;">  is_score</th></tr>
# </thead>
# <tbody>
# <tr><td>PytorchTrainable_a0b0a622</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">0.472085</td><td style="text-align: right;">  5.1721 </td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  5.66282</td><td style="text-align: right;">        6.57903</td><td style="text-align: right;">        4.74459</td><td style="text-align: right;">   200</td><td style="text-align: right;">         737.633</td><td style="text-align: right;">1.29203 </td><td style="text-align: right;">0.98366</td><td style="text-align: right;">   5.76755</td></tr>
# <tr><td>PytorchTrainable_a0b1606c</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">2.22166 </td><td style="text-align: right;">  2.64811</td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  1
td><td>TERMINATED</td><td>     </td><td style="text-align: right;">1.53284 </td><td style="text-align: right;">  2.54219</td><td style="text-align: right;">0.195163</td><td style="text-align: right;">  1.55556</td><td style="text-align: right;">        3.23372</td><td style="text-align: right;">        9.44647</td><td style="text-align: right;">   200</td><td style="text-align: right;">         725.716</td><td style="text-align: right;">2.17651 </td><td style="text-align: right;">1.29347</td><td style="text-align: right;">   5.44131</td></tr>
# </tbody>
# </table><br><br>
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.ImageMagickWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: convert -size 576x576 -depth 8 -delay 100.0 -loop 0 rgba:- ./generated0best.gif
# 2020-11-29 09:31:06,665	WARNING worker.py:1072 -- The node with node id a6b0be5e57f9be7d33f43dc71127ffa2b1c510b4 has been marked dead because the detector has missed too many heartbeats from it.
# (pid=raylet) F1129 09:31:26.657526 23355 23355 node_manager.cc:767]  Check failed: node_id != self_node_id_ Exiting because this node manager has mistakenly been marked dead by the monitor: GCS didn't receive heartbeats within timeout 30000 ms. This is likely since the machine or raylet became overloaded.
# (pid=raylet) *** Check failure stack trace: ***
# (pid=raylet)     @     0x55b9f54539cd  google::LogMessage::Fail()
# (pid=raylet)     @     0x55b9f5454b2c  google::LogMessage::SendToLog()
# (pid=raylet)     @     0x55b9f54536a9  google::LogMessage::Flush()
# (pid=raylet)     @     0x55b9f54538c1  google::LogMessage::~LogMessage()
# (pid=raylet)     @     0x55b9f540bad9  ray::RayLog::~RayLog()
# (pid=raylet)     @     0x55b9f51268f0  ray::raylet::NodeManager::NodeRemoved()
# (pid=raylet)     @     0x55b9f5126acc  _ZNSt17_Function_handlerIFvRKN3ray8ClientIDERKNS0_3rpc11GcsNodeInfoEEZNS0_6raylet11NodeManager11RegisterGcsEvEUlS3_S7_E0_E9_M_invokeERKSt9_Any_dataS3_S7_
# (pid=raylet)     @     0x55b9f5214f48  ray::gcs::ServiceBasedNodeInfoAccessor::HandleNotification()
# (pid=raylet)     @     0x55b9f52151f6  _ZNSt17_Function_handlerIFvRKSsS1_EZZN3ray3gcs28ServiceBasedNodeInfoAccessor26AsyncSubscribeToNodeChangeERKSt8functionIFvRKNS3_8ClientIDERKNS3_3rpc11GcsNodeInfoEEERKS6_IFvNS3_6StatusEEEENKUlSM_E0_clESM_EUlS1_S1_E_E9_M_invokeERKSt9_Any_dataS1_S1_
# (pid=raylet)     @     0x55b9f521f02a  _ZNSt17_Function_handlerIFvSt10shared_ptrIN3ray3gcs13CallbackReplyEEEZNS2_9GcsPubSub24ExecuteCommandIfPossibleERKSsRNS6_7ChannelEEUlS4_E_E9_M_invokeERKSt9_Any_dataS4_
# (pid=raylet)     @     0x55b9f5220b0b  _ZN5boost4asio6detail18completion_handlerIZN3ray3gcs20RedisCallbackManager12CallbackItem8DispatchERSt10shared_ptrINS4_13CallbackReplyEEEUlvE_E11do_completeEPvPNS1_19scheduler_operationERKNS_6system10error_codeEm
# (pid=raylet)     @     0x55b9f575146f  boost::asio::detail::scheduler::do_run_one()
# (pid=raylet)     @     0x55b9f5752971  boost::asio::detail::scheduler::run()
# (pid=raylet)     @     0x55b9f57539a2  boost::asio::io_context::run()
# (pid=raylet)     @     0x55b9f5076fde  main
# (pid=raylet)     @     0x7f6287531bf7  __libc_start_main
# (pid=raylet)     @     0x55b9f508dbb1  (unknown)
